# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv("GDPpercapitadata .csv")
df2 = pd.read_csv("weekly AFR cases by country as of 19 January 2025(in).csv")

# List of African countries
african_countries = [ "Algeria", "Angola", "Benin", "Botswana", "Burkina Faso", "Burundi", "Cabo Verde", "Cameroon", "Central African Republic",
    "Chad", "Comoros", "Democratic Republic of the Congo", "Djibouti", "Egypt", "Equatorial Guinea", "Eritrea", "Eswatini",
    "Ethiopia", "Gabon", "Gambia", "Ghana", "Guinea", "Guinea-Bissau", "Ivory Coast", "Kenya", "Lesotho", "Liberia",
    "Libya", "Madagascar", "Malawi", "Mali", "Mauritania", "Mauritius", "Morocco", "Mozambique", "Namibia", "Niger",
    "Nigeria", "Rwanda", "Sao Tome and Principe", "Senegal", "Seychelles", "Sierra Leone", "Somalia", "South Africa",
    "South Sudan", "Sudan", "Tanzania", "Togo", "Tunisia", "Uganda", "Zambia", "Zimbabwe"
]

# Assuming the column containing country name is called "GDP per capita, current prices(U.S. dollars per capita)"

df_africa = df[df["Countries"].isin(african_countries)]

# Save to a new CSV file
df_africa.to_csv("african_countries_GDP.csv", index=False)

print("Filtered African countries and saved to 'african_countries_GDP.csv'")
# Out:
# Filtered African countries and saved to 'african_countries_GDP.csv'
